# %%
import sys
sys.path.append('/home/ubuntu/arizona/PatchFusion/external')
from estimator.models.patchfusion import PatchFusion

import cv2
import torch
import numpy as np
import torch.nn.functional as F
from torchvision import transforms

# %%
# valid model name:
# 'Zhyever/patchfusion_depth_anything_vits14', 
# 'Zhyever/patchfusion_depth_anything_vitb14', 
# 'Zhyever/patchfusion_depth_anything_vitl14', 
# 'Zhyever/patchfusion_zoedepth'

# %%
# model_name = 'Zhyever/patchfusion_zoedepth'
# model_name = 'Zhyever/patchfusion_depth_anything_vits14'
# model_name = 'Zhyever/patchfusion_depth_anything_vitb14'
# model_name = 'Zhyever/patchfusion_depth_anything_vitl14'
model = PatchFusion.from_pretrained(model_name)

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
model = PatchFusion.from_pretrained(model_name).to(DEVICE).eval()
image_raw_shape = model.tile_cfg['image_raw_shape']
image_resizer = model.resizer

image = cv2.imread(file_path+'./IMG_2635.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) / 255.0
image = transforms.ToTensor()(np.asarray(image)) # raw image

image_lr = image_resizer(image.unsqueeze(dim=0)).float().to(DEVICE)
image_hr = F.interpolate(image.unsqueeze(dim=0), image_raw_shape, mode='bicubic', align_corners=True).float().to(DEVICE)

mode = 'r128' # inference mode
process_num = 4 # batch process size
depth_prediction, _ = model(mode='infer', cai_mode=mode, process_num=process_num, image_lr=image_lr, image_hr=image_hr)
depth_prediction = F.interpolate(depth_prediction, image.shape[-2:])[0, 0].detach().cpu().numpy()

# %%
depth_prediction
# Out:
# array([[3.0915632 , 2.766383  , 2.7387054 , ..., 1.8595821 , 1.8371187 ,
#         1.8069334 ],
#        [2.658399  , 2.754185  , 2.7944329 , ..., 1.887933  , 1.8669019 ,
#         1.8329371 ],
#        [2.7775059 , 2.7980127 , 2.8151789 , ..., 1.9374964 , 1.9323177 ,
#         1.8886588 ],
#        ...,
#        [0.8872943 , 0.8763555 , 0.8780947 , ..., 2.1659868 , 2.1488879 ,
#         2.1349816 ],
#        [0.8842045 , 0.87317216, 0.87712806, ..., 2.148137  , 2.1376834 ,
#         2.1200602 ],
#        [0.8707004 , 0.863938  , 0.8763427 , ..., 2.146774  , 2.1432104 ,
#         2.1445715 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.imshow(depth_prediction, cmap='viridis')

# %%
file_path = '/home/ubuntu/arizona/scade/datasets/scannet/scene0758_00/train/leres_cimle/dump_1102_scene0758_sfmaligned_indv/'

# %%
filename = []
for i in range(20):
    filename.append("1423_{}.npy".format(i))

# %%
i = 0

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 1

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 2

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 3

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 4

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 5

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 6

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 7

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 8

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 9

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 10

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 11

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 12

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 13

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 14

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 15

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 16

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 17

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 18

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 19

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 20

# %%
# tmp = cv2.recmap='rainbow'
tmp = cv2.imread('/home/ubuntu/arizona/scade/datasets/scannet/scene0758_00/image0_2_2-depth.png')

# %%
tmp = cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB)

# %%
from PIL import Image

rainbow_array = tmp

# Convert to grayscale using the luminosity method
def rgb_to_gray(rgb_array):
    return np.dot(rgb_array[...,:3], [0.2989, 0.5870, 0.1140])

gray_array = rgb_to_gray(rainbow_array)

# Normalize the grayscale values to the range [0, 1]
normalized_gray_array = gray_array / 255.0

# Apply the viridis colormap
viridis_img = plt.get_cmap('viridis')(normalized_gray_array)

# Convert back to an image and save
viridis_img = (viridis_img[:, :, :3] * 255).astype(np.uint8)
viridis_img = Image.fromarray(viridis_img)

# %%
import sys
sys.path.append('/home/ubuntu/arizona/PatchFusion/external')
from estimator.models.patchfusion import PatchFusion

import cv2
import torch
import numpy as np
import torch.nn.functional as F
from torchvision import transforms

# %%
# valid model name:
# 'Zhyever/patchfusion_depth_anything_vits14', 
# 'Zhyever/patchfusion_depth_anything_vitb14', 
# 'Zhyever/patchfusion_depth_anything_vitl14', 
# 'Zhyever/patchfusion_zoedepth'

# %%
# model_name = 'Zhyever/patchfusion_zoedepth'
# model_name = 'Zhyever/patchfusion_depth_anything_vits14'
# model_name = 'Zhyever/patchfusion_depth_anything_vitb14'
# model_name = 'Zhyever/patchfusion_depth_anything_vitl14'
model = PatchFusion.from_pretrained(model_name)

# %%
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
model = PatchFusion.from_pretrained(model_name).to(DEVICE).eval()
image_raw_shape = model.tile_cfg['image_raw_shape']
image_resizer = model.resizer

image = cv2.imread(file_path+'./IMG_2635.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) / 255.0
image = transforms.ToTensor()(np.asarray(image)) # raw image

image_lr = image_resizer(image.unsqueeze(dim=0)).float().to(DEVICE)
image_hr = F.interpolate(image.unsqueeze(dim=0), image_raw_shape, mode='bicubic', align_corners=True).float().to(DEVICE)

mode = 'r128' # inference mode
process_num = 4 # batch process size
depth_prediction, _ = model(mode='infer', cai_mode=mode, process_num=process_num, image_lr=image_lr, image_hr=image_hr)
depth_prediction = F.interpolate(depth_prediction, image.shape[-2:])[0, 0].detach().cpu().numpy()

# %%
depth_prediction
# Out:
# array([[3.0915632 , 2.766383  , 2.7387054 , ..., 1.8595821 , 1.8371187 ,
#         1.8069334 ],
#        [2.658399  , 2.754185  , 2.7944329 , ..., 1.887933  , 1.8669019 ,
#         1.8329371 ],
#        [2.7775059 , 2.7980127 , 2.8151789 , ..., 1.9374964 , 1.9323177 ,
#         1.8886588 ],
#        ...,
#        [0.8872943 , 0.8763555 , 0.8780947 , ..., 2.1659868 , 2.1488879 ,
#         2.1349816 ],
#        [0.8842045 , 0.87317216, 0.87712806, ..., 2.148137  , 2.1376834 ,
#         2.1200602 ],
#        [0.8707004 , 0.863938  , 0.8763427 , ..., 2.146774  , 2.1432104 ,
#         2.1445715 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
plt.imshow(depth_prediction, cmap='viridis')

# %%
file_path = '/home/ubuntu/arizona/scade/datasets/scannet/scene0758_00/train/leres_cimle/dump_1102_scene0758_sfmaligned_indv/'

# %%
filename = []
for i in range(20):
    filename.append("1423_{}.npy".format(i))

# %%
i = 0

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 1

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 2

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 3

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 4

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 5

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 6

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 7

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 8

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 9

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 10

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 11

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 12

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 13

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 14

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 15

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 16

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 17

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 18

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 19

# %%
path = file_path+filename[i]
plt.imshow(np.load(path), cmap='viridis')
i = i+1
print(i)
# Out:
# 20

# %%
# tmp = cv2.recmap='rainbow'
tmp = cv2.imread('/home/ubuntu/arizona/scade/datasets/scannet/scene0758_00/image0_2_2-depth.png')

# %%
tmp = cv2.cvtColor(tmp, cv2.COLOR_BGR2RGB)

# %%
from PIL import Image

rainbow_array = tmp

# Convert to grayscale using the luminosity method
def rgb_to_gray(rgb_array):
    return np.dot(rgb_array[...,:3], [0.2989, 0.5870, 0.1140])

gray_array = rgb_to_gray(rainbow_array)

# Normalize the grayscale values to the range [0, 1]
normalized_gray_array = gray_array / 255.0

# Apply the viridis colormap
viridis_img = plt.get_cmap('viridis')(normalized_gray_array)

# Convert back to an image and save
viridis_img = (viridis_img[:, :, :3] * 255).astype(np.uint8)
viridis_img = Image.fromarray(viridis_img)
